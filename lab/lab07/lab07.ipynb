# %% [markdown]
# <img src="./ccsf.png" alt="CCSF Logo" width=200px style="margin:0px -5px">

# %% [markdown]
# # Lab 07 - A/B Testing

# %% [markdown]
# ## References

# %% [markdown]
# * [Sections 11.3 - 11.4](https://ccsf-math-108.github.io/textbook/chapters/11/3/Decisions_and_Uncertainty.html)
# * [Sections 12.0 - 12.3 of the Textbook](https://ccsf-math-108.github.io/textbook/chapters/12/Comparing_Two_Samples.html)
# * [datascience Documentation](https://datascience.readthedocs.io/)
# * [Code Reference](https://ccsf-math-108.github.io/materials-sp26/resources/code-reference.html)

# %% [markdown]
# ---

# %% [markdown]
# ## Lab Assignment Reminders

# %% [markdown]
# - 🚨 Make sure to run the code cell at the top of this notebook that starts with `# Initialize Otter` to load the auto-grader.
# - Your tasks are categorized as auto-graded (📍) and manually graded (📍🔎):
#     - **For all auto-graded tasks:**
#         - Replace the `...` in the provided code cell with your own code.
#         - Run the `grader.check` code cell to execute tests on your code.
#         - There are no hidden auto-grader tests in the lab assignments. This means if you pass the tests, you can assume you've completed the task successfully.
#     - **For all manually graded tasks:**
#         - You may need to provide your own response to the provided prompt. Replace the template text "_Type your answer here, replacing this text._" with your own words.
#         - You might need to produce a graphic or another output using code. Replace the `...` in the code cell to generate the image, table, etc.
#         - In either case, check your response with a classmate, a tutor, or the instructor before moving on.
# - Throughout this assignment and all future ones, please **do not re-assign variables** throughout the notebook! _For example, if you use `max_temperature` in your answer to one question, do not reassign it later on. Otherwise, you may fail tests that you thought you were passing previously!_
# - You may [submit](#Submit-Your-Assignment-to-Canvas) this assignment as many times as you want before the deadline. Your instructor will score the last version you submit once the deadline has passed.
# - **Collaborating on labs is encouraged!** You should rarely remain stuck for more than a few minutes on questions in labs, so ask an instructor or classmate for help. (Explaining things is beneficial, too -- the best way to solidify your knowledge of a subject is to explain it.) However, please don't just share answers.

# %% [markdown]
# ---

# %% [markdown]
# ## Set Up Notebook

# %% [markdown]
# ### Task 00 📍

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Run the following code cells to set up the notebook.
#
# _You are not responsible for understanding what this code does._

# %%
# Initialize Otter
import otter
grader = otter.Notebook('lab07.ipynb')

# %%
# Configure this Notebook
import numpy as np
from datascience import *
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# <!-- END QUESTION -->
#
# ---

# %% [markdown]
# ## A/B Testing

# %% [markdown]
# ---

# %% [markdown]
# A/B testing is a form of hypothesis testing that allows you to make comparisons between two distributions. We may also refer to an A/B test as a permutation test.
#
# You'll almost never be explicitly asked to perform an A/B test. Make sure you can identify situations where the test is appropriate and know how to correctly implement each step. Oftentimes, we use an A/B test to determine whether or not two samples came from the same underlying distribution.

# %% [markdown]
# ---

# %% [markdown]
# ### Task 01 📍

# %% [markdown]
# The following statements are the steps of an A/B hypothesis test presented in a random order:
#
# 1. Choose a test statistic (typically the difference in means between two categories)
# 1. Shuffle the labels of the original sample, find your simulated test statistic, and repeat many times
# 1. Find the value of the observed test statistic
# 1. Calculate the p-value based on your observed and simulated test statistics
# 1. Define a null and alternate model
# 1. Use the p-value and p-value cutoff to draw a conclusion about the null hypothesis
#
# Assign `ab_test_order` to an array of integers that contains the correct order of an A/B test, where the first item of the array is the first step of an A/B test and the last item of the array is the last step of an A/B test.

# %%
ab_test_order = ...
ab_test_order

# %%
grader.check("task_01")

# %% [markdown]
# ---

# %% [markdown]
# ## Major League Baseball (MLB) Pitch Clock

# %% [markdown]
# ---

# %% [markdown]
# >"On September 8, 2022, MLB announced that rules changes for 2023 included the use of a pitch clock. Pitchers would have 15 seconds between pitches when there are no baserunners and 20 seconds if there is at least one baserunner. Also, the batter will have seven to twelve seconds to be in the stance ready to hit, or an automatic strike will be called. The clock starts when the pitcher gets the ball and the catcher and batter are ready." [Source: Wikipedia](https://en.wikipedia.org/wiki/Pitch_clock)
#
# Between the 2022 and 2023 baseball seasons, MLB introduced a “pitch clock” – a series of rules that dictate how much time is allowed to pass between pitches. Although it was never the “official reason” for the rule, the hope for MLB is that it would help shorten the length of games.
#
# NOTE: There were many other rule changes introduced at the same time as the pitch clock.

# %% [markdown]
# ---

# %% [markdown]
# ## Task 02 📍🔎

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# We want to know whether the pitch clock made a significant decrease in the length of games. Why is it not sufficient to compare the average game length from before the pitch clock was instated to the average game length after the pitch clock was instated?
#
# _Check your response with someone else before moving on._

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ---

# %% [markdown]
# We are going to run the following hypothesis test to determine the association between the pitch clock and the game length. The population we are examining is all of MLB, but the data we will use will contain only San Francisco Giants games from the 2022 and 2023 seasons &mdash; the last year before the pitch clock and first year after pitch clock. We are going to use the following null and alternative hypotheses:
#
# **Null hypothesis:** The distribution of game length in 2022 (before the clock) and 2023 (after) are the same.
#
# **Alternative hypothesis:** Game lengths are shorter in 2023 (after) than in 2022 (before), on average.
#
# Our alternative hypothesis is related to our suspicion that MLB introduced it to shorten games.

# %% [markdown]
# The `game_length` table below describes the length of every game (in minutes) and whether the game was from before or after the pitch clock. Values for before are `0`, and values for after are `1`. The data excludes games that went to "extra-innings". [Source: Baseball Reference](https://www.baseball-reference.com/)

# %%
game_length = Table.read_table("game_length.csv")
game_length.show(3)

# %% [markdown]
# ---

# %% [markdown]
# ## Task 03 📍

# %% [markdown]
# Create a new table called `means` that contains the mean game length for games before and after the pitch clock. The table should have the column names `Pitch Clock` and `Time (minutes) mean`.

# %%
means = ...
means

# %%
grader.check("task_03")

# %% [markdown]
# ---

# %% [markdown]
# ## Task 04 📍🔎

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Visualize the distribution of game length for before and after the pitch clock as overlaid histograms. Make sure to:
#
# * Use the bins we provided.
# * Use the group argument of `tbl.hist`. In order to produce several overlayed histograms based on unique values in a given column, we can do something like `tbl.hist(..., group=<col_name>, bins=...)`!
#
# _We recommend that you check your histogram with someone before moving on._

# %%
useful_bins = np.arange(115, 240,10)
...

# %% [markdown]
# <!-- END QUESTION -->
#
# ---

# %% [markdown]
# ## Task 05 📍🔎

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# We want to figure out if there is a difference between the distribution of game length between before and after the pitch clock was instated. For the test statistic, subtract the mean game length value for games before the pitch clock from the mean value for games after.
#
# Which values of this test statistic support the alternative hypothesis?
#
# _Before moving on, confirm your answer with someone._

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ---

# %% [markdown]
# ## Task 06 📍

# %% [markdown]
# Set `observed_difference` to the observed test statistic using the `means` table.

# %%
observed_difference = ...
observed_difference

# %%
grader.check("task_06")

# %% [markdown]
# ---

# %% [markdown]
# ## Task 07 📍

# %% [markdown]
# In the next task, you will be writing a function to calculate the test statistic on any table similar to `game_length`, but with the column labels shuffled around.
#
# In this task, you will write a function `find_test_stat` that calculates the test statistic outlined above. The function should input a table `tbl`, a label column `label_col` with two labels, `1` and `0`, and a values column `val_col`,
#
# *Hint*: Make sure that you are taking the directionality of our alternative hypothesis into account.

# %%
def find_test_stat(tbl, label_col, val_col):
    ...

# Confirm that your function produces the same observed difference
find_test_stat(game_length, "Pitch Clock", "Time (minutes)")

# %%
grader.check("task_07")

# %% [markdown]
# ---

# %% [markdown]
# When we run a simulation for A/B testing, we resample by **shuffling the labels** of the original sample. If the null hypothesis is true and the game length distributions are the same, we expect that the difference in mean game length to not change when `"Pitch Clock"` labels are changed.

# %% [markdown]
# ---

# %% [markdown]
# ## Task 08 📍

# %% [markdown]
# In the next task we will simulate many repetitions of an A/B test.
#
# In this task you will write a function `simulate_and_test_statistic` to run one trial of our A/B test (i.e. resmaple by shuffling the labels) and compute the test statistic we want. Your function should input a table, a column label to use for shuffling, and the values column. The function should return our desired test statistic.

# %%
def simulate_and_test_statistic(tbl, labels_col, values_col):
    ...

simulate_and_test_statistic(game_length, "Pitch Clock", "Time (minutes)")

# %%
grader.check("task_08")

# %% [markdown]
# ---

# %% [markdown]
# ## Task 09 📍

# %% [markdown]
# Now that you have written a function to simulate one trial of our A/B test, in this task simulate 5000 trials of our A/B test and store the test statistics in an array called `differences`. Once complete, this code cell will take a few minutes to run.

# %%
repetitions = ...
differences = ...

...                                              

differences

# %%
grader.check("task_09")

# %% [markdown]
# Run the cell below to view a histogram of your simulated test statistics plotted with your observed test statistic.

# %%
Table().with_column('Difference Between Group Means', differences).hist(bins=20)
plt.scatter(observed_difference, 0, color='red', s=30, zorder=10)
plt.ylim(-0.01, 0.15);

# %% [markdown]
# ---

# %% [markdown]
# ## Task 10 📍

# %% [markdown]
# Find the p-value for your test and assign it to `p_value`.

# %%
p_value = ...                                             

p_value

# %%
grader.check("task_10")

# %% [markdown]
# ---

# %% [markdown]
# ## Task 11 📍🔎

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# 1. Using a 5% p-value cutoff, draw a conclusion about the null and alternative hypotheses using more the technical language of hypothesis testing.
# 2. Using simple, non-technical language, what does your analysis tell you about the association between game length and the use of the pitch clock?
# 3. What can you claim about causation from your statistical analysis?
#
# Confirm your answer with a peer, instructor, etc.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ---

# %% [markdown]
# ## Final Task 📍

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# You're almost done! Run the cell below to check that you passed all of the non-hidden auto-graded tasks, and then follow the instructions below to submit your assignment to Canvas.

# %%
grader.check_all()

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Submit Your Assignment to Canvas

# %% [markdown]
# Follow these steps to submit your lab assignment:
#
# 1. **Check the Assignment Completion Requirements:** This assignment is scored as Complete or Incomplete. Make sure to check with your instructor about their requirements for a Complete score.
# 2. **Run the Auto-Grader:** Ensure you have executed the code cell containing the command `grader.check_all()` above, to run all tests for auto-graded tasks marked with 📍. This command will execute all auto-grader tests sequentially.
# 3. **Complete Manually Graded Tasks:** Verify that you have responded to all the manually graded tasks marked with 📍🔎.
# 4. **Save Your Work:** In the notebook's Toolbar, go to `File -> Save Notebook` to save your work and create a checkpoint.
# 5. **Download the Notebook:** In the notebook's Toolbar, go to `File -> Download HTML` to download the HTML version (`.html`) of this notebook.
# 6. **Upload to Canvas:** On the Canvas Assignment page, click "Start Assignment" or "New Attempt" to upload the downloaded `.html` file.

# %% [markdown]
# ---

# %% [markdown]
# ## Attribution

# %% [markdown]
# This content is licensed under the <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (CC BY-NC-SA 4.0)</a> and derived from the <a href="https://www.data8.org/">Data 8: The Foundations of Data Science</a> offered by the University of California, Berkeley.
#
# <img src="./by-nc-sa.png" width=100px>
